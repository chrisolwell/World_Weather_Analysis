# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy
import time

# import requests
import requests
# from config import weather_api_key
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and longs to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities=[]
#Identify the nearest city for each lat and lon combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#Print the city count tto confirm sufficient count.
#len(cities)
#print(cities)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=51c0ecd113242f8999d9c1d84d8f5b68

# %%
# # Create an endpoint URL for a city.
city_url = url + "&q=" + "boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=51c0ecd113242f8999d9c1d84d8f5b68&q=boston

# %%
# CREate an empty list to hold the weather data
city_data = []
#print the beginning to the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")
#create counters
record_count = 1
set_count = 1

#Loop through all the cities in our list.
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count =1
        time.sleep(60)
        
    #Create andpoint url with each city
    #print(city)
    city_url = url + "&q=" + city.replace(" ","+")
    #With Reza, worked to find problems with API key using the print function below.)
    #print(city_url)

    #Log the url, record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count +=1
    
#Run and API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #parse the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_winds = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        #convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #append the city info into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_winds,
                          "Country": city_country,
                          "Current Weather": city_description
        })
        
#If an error is experienced, skip the city
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass
    
#Indicate that Data Loading is complete
print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | mayumba
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | komatipoort
# Processing Record 4 of Set 1 | ridgecrest
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | bacuit
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | mto wa mbu
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | hamilton
# Processing Record 13 of Set 1 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 1 | vila franca do campo
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | general pico
# Processing Record 19 of Set 1 | pevek
# Processing Record 20 of Set 1 | shimoda
# Processing Record 21 of Set 1 | south sioux city
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | nagato
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | mbini
# Processing Record 26 of Set 1 | kattivakkam
# Processing Record 27 of Set 1 | bengkulu
# Processing Record 28 of Set 1 | oussouye
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | cayhagan
# Processing Record 33 of Set 1 | lazaro cardenas
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | bereda
# Processing Record 36 of Set 1 | brae
# Processing Record 37 of Set 1 | karratha
# Processing Record 38 of Set 1 | mount isa
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 1 | katangli
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | tateyama
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | olinda
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | hervey bay
# Processing Record 3 of Set 2 | nantucket
# Processing Record 4 of Set 2 | damghan
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | springfield
# Processing Record 8 of Set 2 | batemans bay
# Processing Record 9 of Set 2 | nikolskoye
# Processing Record 10 of Set 2 | bangassou
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | george town
# Processing Record 13 of Set 2 | nishihara
# Processing Record 14 of Set 2 | kyrylivka
# Processing Record 15 of Set 2 | kiunga
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | valparaiso
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | dinsor
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 2 | guerrero negro
# Processing Record 21 of Set 2 | high rock
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | ust-charyshskaya pristan
# Processing Record 25 of Set 2 | cururupu
# Processing Record 26 of Set 2 | dunda
# Processing Record 27 of Set 2 | karaton
# Processing Record 28 of Set 2 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 2 | moa
# Processing Record 30 of Set 2 | coquimbo
# Processing Record 31 of Set 2 | haines junction
# Processing Record 32 of Set 2 | touros
# Processing Record 33 of Set 2 | namatanai
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | saskylakh
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | san joaquin
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | tongchuan
# Processing Record 40 of Set 2 | roald
# Processing Record 41 of Set 2 | balakhninskiy
# Processing Record 42 of Set 2 | fairbanks
# Processing Record 43 of Set 2 | henties bay
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | la grande
# Processing Record 46 of Set 2 | cap malheureux
# Processing Record 47 of Set 2 | agbor
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | baykit
# Processing Record 50 of Set 2 | coracao de jesus
# Processing Record 1 of Set 3 | quatre cocos
# Processing Record 2 of Set 3 | vila
# Processing Record 3 of Set 3 | payakumbuh
# Processing Record 4 of Set 3 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 3 | hilo
# Processing Record 6 of Set 3 | anloga
# Processing Record 7 of Set 3 | faanui
# Processing Record 8 of Set 3 | eureka
# Processing Record 9 of Set 3 | ampanihy
# Processing Record 10 of Set 3 | kieta
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | ambunti
# Processing Record 14 of Set 3 | povenets
# Processing Record 15 of Set 3 | barra da estiva
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | baghmara
# Processing Record 20 of Set 3 | tayoltita
# Processing Record 21 of Set 3 | acarau
# Processing Record 22 of Set 3 | luderitz
# Processing Record 23 of Set 3 | dotnuva
# Processing Record 24 of Set 3 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 3 | tasiilaq
# Processing Record 26 of Set 3 | faya
# Processing Record 27 of Set 3 | deputatskiy
# Processing Record 28 of Set 3 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 3 | bojnurd
# Processing Record 30 of Set 3 | luanda
# Processing Record 31 of Set 3 | mehamn
# Processing Record 32 of Set 3 | marsabit
# Processing Record 33 of Set 3 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 3 | fuling
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | toora-khem
# Processing Record 37 of Set 3 | kruisfontein
# Processing Record 38 of Set 3 | tinskoy
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | taiyuan
# Processing Record 41 of Set 3 | port-gentil
# Processing Record 42 of Set 3 | egvekinot
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | lamar
# Processing Record 45 of Set 3 | lavrentiya
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | port blair
# Processing Record 48 of Set 3 | kadykchan
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 3 | fare
# Processing Record 50 of Set 3 | sulangan
# Processing Record 1 of Set 4 | dikson
# Processing Record 2 of Set 4 | preston
# Processing Record 3 of Set 4 | sechura
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | tuktoyaktuk
# Processing Record 6 of Set 4 | bodden town
# Processing Record 7 of Set 4 | provideniya
# Processing Record 8 of Set 4 | port hardy
# Processing Record 9 of Set 4 | novobirilyussy
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | laguna
# Processing Record 12 of Set 4 | maarianhamina
# Processing Record 13 of Set 4 | salym
# Processing Record 14 of Set 4 | souillac
# Processing Record 15 of Set 4 | bandarbeyla
# Processing Record 16 of Set 4 | devonport
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | cabedelo
# Processing Record 19 of Set 4 | sovetskiy
# Processing Record 20 of Set 4 | srednekolymsk
# Processing Record 21 of Set 4 | kununurra
# Processing Record 22 of Set 4 | sao filipe
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | merauke
# Processing Record 25 of Set 4 | paraiso
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | nikolayevsk-na-amure
# Processing Record 28 of Set 4 | hobart
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | tambopata
# Processing Record 31 of Set 4 | port alfred
# Processing Record 32 of Set 4 | jinhua
# Processing Record 33 of Set 4 | fukue
# Processing Record 34 of Set 4 | mandalgovi
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | yining
# Processing Record 37 of Set 4 | lorengau
# Processing Record 38 of Set 4 | ixtapa
# Processing Record 39 of Set 4 | trairi
# Processing Record 40 of Set 4 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 4 | cidreira
# Processing Record 42 of Set 4 | pervomayskiy
# Processing Record 43 of Set 4 | clyde river
# Processing Record 44 of Set 4 | chase
# Processing Record 45 of Set 4 | arlit
# Processing Record 46 of Set 4 | belmonte
# Processing Record 47 of Set 4 | roswell
# Processing Record 48 of Set 4 | vestmanna
# Processing Record 49 of Set 4 | lebu
# Processing Record 50 of Set 4 | reyes
# Processing Record 1 of Set 5 | brusyanskiy
# Processing Record 2 of Set 5 | kirovskiy
# Processing Record 3 of Set 5 | eyl
# Processing Record 4 of Set 5 | verkhnevilyuysk
# Processing Record 5 of Set 5 | pailon
# Processing Record 6 of Set 5 | karaul
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | mount gambier
# Processing Record 9 of Set 5 | half moon bay
# Processing Record 10 of Set 5 | viligili
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 5 | muisne
# Processing Record 12 of Set 5 | bend
# Processing Record 13 of Set 5 | lasa
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | vila velha
# Processing Record 16 of Set 5 | airai
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | maniitsoq
# Processing Record 19 of Set 5 | nyagan
# Processing Record 20 of Set 5 | solnechnyy
# Processing Record 21 of Set 5 | hvammstangi
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 5 | sarangani
# Processing Record 23 of Set 5 | puerto ayora
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | barwani
# Processing Record 26 of Set 5 | kitimat
# Processing Record 27 of Set 5 | aklavik
# Processing Record 28 of Set 5 | abdanan
# Processing Record 29 of Set 5 | balkhash
# Processing Record 30 of Set 5 | saint-augustin
# Processing Record 31 of Set 5 | cayenne
# Processing Record 32 of Set 5 | riyadh
# Processing Record 33 of Set 5 | ostrovnoy
# Processing Record 34 of Set 5 | lata
# Processing Record 35 of Set 5 | barquisimeto
# Processing Record 36 of Set 5 | conceicao da barra
# Processing Record 37 of Set 5 | arbuzynka
# Processing Record 38 of Set 5 | kavaratti
# Processing Record 39 of Set 5 | lavumisa
# Processing Record 40 of Set 5 | caravelas
# Processing Record 41 of Set 5 | krasnyye baki
# Processing Record 42 of Set 5 | tautira
# Processing Record 43 of Set 5 | trincomalee
# Processing Record 44 of Set 5 | zhuhai
# Processing Record 45 of Set 5 | oranjemund
# Processing Record 46 of Set 5 | mankono
# Processing Record 47 of Set 5 | paradwip
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | pisco
# Processing Record 50 of Set 5 | zhangjiakou
# Processing Record 1 of Set 6 | dwarka
# Processing Record 2 of Set 6 | bethel
# Processing Record 3 of Set 6 | khanpur
# Processing Record 4 of Set 6 | hami
# Processing Record 5 of Set 6 | dzhebariki-khaya
# Processing Record 6 of Set 6 | papar
# Processing Record 7 of Set 6 | adrar
# Processing Record 8 of Set 6 | ndola
# Processing Record 9 of Set 6 | tabiauea
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 6 | beidao
# Processing Record 11 of Set 6 | marsh harbour
# Processing Record 12 of Set 6 | mayna
# Processing Record 13 of Set 6 | washougal
# Processing Record 14 of Set 6 | hithadhoo
# Processing Record 15 of Set 6 | khash
# Processing Record 16 of Set 6 | tarakan
# Processing Record 17 of Set 6 | san rafael
# Processing Record 18 of Set 6 | longyearbyen
# Processing Record 19 of Set 6 | kirkconnel
# Processing Record 20 of Set 6 | hirara
# Processing Record 21 of Set 6 | mackenzie
# Processing Record 22 of Set 6 | lamu
# Processing Record 23 of Set 6 | yuzhno-yeniseyskiy
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 6 | ode
# Processing Record 25 of Set 6 | udon thani
# Processing Record 26 of Set 6 | rio gallegos
# Processing Record 27 of Set 6 | kahului
# Processing Record 28 of Set 6 | yatou
# Processing Record 29 of Set 6 | atar
# Processing Record 30 of Set 6 | corralillo
# Processing Record 31 of Set 6 | kushima
# Processing Record 32 of Set 6 | huarmey
# Processing Record 33 of Set 6 | esil
# Processing Record 34 of Set 6 | huaidian
# Processing Record 35 of Set 6 | asyut
# Processing Record 36 of Set 6 | sao domingos
# Processing Record 37 of Set 6 | san carlos de bariloche
# Processing Record 38 of Set 6 | zhigansk
# Processing Record 39 of Set 6 | sabha
# Processing Record 40 of Set 6 | dryden
# Processing Record 41 of Set 6 | bima
# Processing Record 42 of Set 6 | yanchukan
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 6 | udalguri
# Processing Record 44 of Set 6 | bathsheba
# Processing Record 45 of Set 6 | fortuna
# Processing Record 46 of Set 6 | klaksvik
# Processing Record 47 of Set 6 | nome
# Processing Record 48 of Set 6 | tocopilla
# Processing Record 49 of Set 6 | pacific grove
# Processing Record 50 of Set 6 | san cristobal
# Processing Record 1 of Set 7 | dongkan
# Processing Record 2 of Set 7 | portland
# Processing Record 3 of Set 7 | gat
# Processing Record 4 of Set 7 | samana
# Processing Record 5 of Set 7 | plettenberg bay
# Processing Record 6 of Set 7 | the valley
# Processing Record 7 of Set 7 | sekoma
# Processing Record 8 of Set 7 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 7 | walvis bay
# Processing Record 10 of Set 7 | gerede
# Processing Record 11 of Set 7 | vikulovo
# Processing Record 12 of Set 7 | thompson
# Processing Record 13 of Set 7 | marsa matruh
# Processing Record 14 of Set 7 | campbell river
# Processing Record 15 of Set 7 | yumen
# Processing Record 16 of Set 7 | east london
# Processing Record 17 of Set 7 | margate
# Processing Record 18 of Set 7 | talnakh
# Processing Record 19 of Set 7 | vinh
# Processing Record 20 of Set 7 | waipawa
# Processing Record 21 of Set 7 | ribeira grande
# Processing Record 22 of Set 7 | sorland
# Processing Record 23 of Set 7 | chernyshevskiy
# Processing Record 24 of Set 7 | teguise
# Processing Record 25 of Set 7 | elena
# Processing Record 26 of Set 7 | pangnirtung
# Processing Record 27 of Set 7 | pacasmayo
# Processing Record 28 of Set 7 | kodiak
# Processing Record 29 of Set 7 | bambanglipuro
# Processing Record 30 of Set 7 | mandali
# Processing Record 31 of Set 7 | herat
# Processing Record 32 of Set 7 | lompoc
# Processing Record 33 of Set 7 | sur
# Processing Record 34 of Set 7 | moussoro
# Processing Record 35 of Set 7 | buin
# Processing Record 36 of Set 7 | bur gabo
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 7 | geraldton
# Processing Record 38 of Set 7 | pangkalanbuun
# Processing Record 39 of Set 7 | hays
# Processing Record 40 of Set 7 | alappuzha
# Processing Record 41 of Set 7 | leningradskiy
# Processing Record 42 of Set 7 | port lincoln
# Processing Record 43 of Set 7 | guayaramerin
# Processing Record 44 of Set 7 | zhongshu
# Processing Record 45 of Set 7 | limoux
# Processing Record 46 of Set 7 | ayan
# Processing Record 47 of Set 7 | kloulklubed
# Processing Record 48 of Set 7 | mlonggo
# Processing Record 49 of Set 7 | juba
# Processing Record 50 of Set 7 | narsaq
# Processing Record 1 of Set 8 | matara
# Processing Record 2 of Set 8 | ruatoria
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 8 | porto walter
# Processing Record 4 of Set 8 | palana
# Processing Record 5 of Set 8 | udachnyy
# Processing Record 6 of Set 8 | whitianga
# Processing Record 7 of Set 8 | coruripe
# Processing Record 8 of Set 8 | ballina
# Processing Record 9 of Set 8 | paracuru
# Processing Record 10 of Set 8 | toktogul
# Processing Record 11 of Set 8 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 8 | champasak
# Processing Record 13 of Set 8 | pogar
# Processing Record 14 of Set 8 | kasempa
# Processing Record 15 of Set 8 | sitka
# Processing Record 16 of Set 8 | tazovskiy
# Processing Record 17 of Set 8 | puerto colombia
# Processing Record 18 of Set 8 | laibin
# Processing Record 19 of Set 8 | aksu
# Processing Record 20 of Set 8 | manavgat
# Processing Record 21 of Set 8 | labuhan
# Processing Record 22 of Set 8 | lerwick
# Processing Record 23 of Set 8 | areia branca
# Processing Record 24 of Set 8 | sterling
# Processing Record 25 of Set 8 | rodrigues alves
# Processing Record 26 of Set 8 | westpunt
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 8 | ulefoss
# Processing Record 28 of Set 8 | ozernovskiy
# Processing Record 29 of Set 8 | imbituba
# Processing Record 30 of Set 8 | tual
# Processing Record 31 of Set 8 | belyy yar
# Processing Record 32 of Set 8 | umkomaas
# Processing Record 33 of Set 8 | ust-nera
# Processing Record 34 of Set 8 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 8 | comodoro rivadavia
# Processing Record 36 of Set 8 | dafeng
# Processing Record 37 of Set 8 | katobu
# Processing Record 38 of Set 8 | eldorado
# Processing Record 39 of Set 8 | yulara
# Processing Record 40 of Set 8 | azimur
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 8 | jalu
# Processing Record 42 of Set 8 | sistranda
# Processing Record 43 of Set 8 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 8 | nyandoma
# Processing Record 45 of Set 8 | ashdod
# Processing Record 46 of Set 8 | sola
# Processing Record 47 of Set 8 | juneau
# Processing Record 48 of Set 8 | arraial do cabo
# Processing Record 49 of Set 8 | maragogi
# Processing Record 50 of Set 8 | wanning
# Processing Record 1 of Set 9 | chifeng
# Processing Record 2 of Set 9 | uttaradit
# Processing Record 3 of Set 9 | katsuura
# Processing Record 4 of Set 9 | santa rosa
# Processing Record 5 of Set 9 | yamada
# Processing Record 6 of Set 9 | ambovombe
# Processing Record 7 of Set 9 | lucera
# Processing Record 8 of Set 9 | bakel
# Processing Record 9 of Set 9 | nioaque
# Processing Record 10 of Set 9 | winnemucca
# Processing Record 11 of Set 9 | jiuquan
# Processing Record 12 of Set 9 | yakima
# Processing Record 13 of Set 9 | nanortalik
# Processing Record 14 of Set 9 | nevsehir
# Processing Record 15 of Set 9 | barawe
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 9 | payo
# Processing Record 17 of Set 9 | jiddah
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 9 | bayan
# Processing Record 19 of Set 9 | xining
# Processing Record 20 of Set 9 | khani
# Processing Record 21 of Set 9 | komsomolskiy
# Processing Record 22 of Set 9 | whyalla
# Processing Record 23 of Set 9 | behshahr
# Processing Record 24 of Set 9 | enshi
# Processing Record 25 of Set 9 | mamou
# Processing Record 26 of Set 9 | santa isabel
# Processing Record 27 of Set 9 | kamina
# Processing Record 28 of Set 9 | daxian
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 9 | kamenka
# Processing Record 30 of Set 9 | tidore
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 9 | northam
# Processing Record 32 of Set 9 | kutum
# Processing Record 33 of Set 9 | bull savanna
# Processing Record 34 of Set 9 | jalingo
# Processing Record 35 of Set 9 | tukrah
# Processing Record 36 of Set 9 | banepa
# Processing Record 37 of Set 9 | saldanha
# Processing Record 38 of Set 9 | witu
# Processing Record 39 of Set 9 | okhotsk
# Processing Record 40 of Set 9 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 9 | lagoa
# Processing Record 42 of Set 9 | aswan
# Processing Record 43 of Set 9 | baruun-urt
# Processing Record 44 of Set 9 | boralday
# Processing Record 45 of Set 9 | quthing
# Processing Record 46 of Set 9 | tsaratanana
# Processing Record 47 of Set 9 | ambajogai
# Processing Record 48 of Set 9 | marawi
# Processing Record 49 of Set 9 | ulaangom
# Processing Record 50 of Set 9 | goteborg
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 10 | hunza
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 10 | bababe
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 10 | omaruru
# Processing Record 4 of Set 10 | raudeberg
# Processing Record 5 of Set 10 | presidente olegario
# Processing Record 6 of Set 10 | gap
# Processing Record 7 of Set 10 | bantry
# Processing Record 8 of Set 10 | krasnyy chikoy
# Processing Record 9 of Set 10 | gao
# Processing Record 10 of Set 10 | araouane
# Processing Record 11 of Set 10 | pangody
# Processing Record 12 of Set 10 | axim
# Processing Record 13 of Set 10 | sao joao da barra
# Processing Record 14 of Set 10 | shashi
# Processing Record 15 of Set 10 | nizhniy lomov
# Processing Record 16 of Set 10 | bargal
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 10 | burglengenfeld
# Processing Record 18 of Set 10 | ambodifototra
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 10 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 10 | yabelo
# Processing Record 21 of Set 10 | husavik
# Processing Record 22 of Set 10 | burgeo
# Processing Record 23 of Set 10 | santiago del estero
# Processing Record 24 of Set 10 | sibolga
# Processing Record 25 of Set 10 | popondetta
# Processing Record 26 of Set 10 | mindelo
# Processing Record 27 of Set 10 | puerto leguizamo
# Processing Record 28 of Set 10 | pathein
# Processing Record 29 of Set 10 | tabulbah
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 10 | babanusah
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 10 | tabou
# Processing Record 32 of Set 10 | abha
# Processing Record 33 of Set 10 | atasu
# Processing Record 34 of Set 10 | goderich
# Processing Record 35 of Set 10 | tiznit
# Processing Record 36 of Set 10 | sao geraldo do araguaia
# Processing Record 37 of Set 10 | san quintin
# Processing Record 38 of Set 10 | port hedland
# Processing Record 39 of Set 10 | shahr-e babak
# Processing Record 40 of Set 10 | puerto cortes
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 10 | tefe
# Processing Record 42 of Set 10 | buchanan
# Processing Record 43 of Set 10 | miandrivazo
# Processing Record 44 of Set 10 | sao gabriel da cachoeira
# Processing Record 45 of Set 10 | manta
# Processing Record 46 of Set 10 | garowe
# Processing Record 47 of Set 10 | ihosy
# Processing Record 48 of Set 10 | tanggu
# Processing Record 49 of Set 10 | muros
# Processing Record 50 of Set 10 | ahipara
# Processing Record 1 of Set 11 | palu
# Processing Record 2 of Set 11 | naftah
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 11 | opelousas
# Processing Record 4 of Set 11 | vardo
# Processing Record 5 of Set 11 | aurillac
# Processing Record 6 of Set 11 | westport
# Processing Record 7 of Set 11 | terra santa
# Processing Record 8 of Set 11 | najran
# Processing Record 9 of Set 11 | anchorage
# Processing Record 10 of Set 11 | fort nelson
# Processing Record 11 of Set 11 | tigil
# Processing Record 12 of Set 11 | ilulissat
# Processing Record 13 of Set 11 | vilhena
# Processing Record 14 of Set 11 | ranong
# Processing Record 15 of Set 11 | rey bouba
# Processing Record 16 of Set 11 | biharamulo
# Processing Record 17 of Set 11 | tromso
# Processing Record 18 of Set 11 | qaqortoq
# Processing Record 19 of Set 11 | yaan
# Processing Record 20 of Set 11 | sesheke
# Processing Record 21 of Set 11 | inhambane
# Processing Record 22 of Set 11 | simao
# Processing Record 23 of Set 11 | joensuu
# Processing Record 24 of Set 11 | pietarsaari
# Processing Record 25 of Set 11 | dapaong
# Processing Record 26 of Set 11 | kurilsk
# Processing Record 27 of Set 11 | atbasar
# Processing Record 28 of Set 11 | chhabra
# Processing Record 29 of Set 11 | havelock
# Processing Record 30 of Set 11 | barcelos
# Processing Record 31 of Set 11 | dhali
# Processing Record 32 of Set 11 | wattegama
# Processing Record 33 of Set 11 | whitehorse
# Processing Record 34 of Set 11 | coihaique
# Processing Record 35 of Set 11 | bakchar
# Processing Record 36 of Set 11 | kenai
# Processing Record 37 of Set 11 | makakilo city
# Processing Record 38 of Set 11 | vetlanda
# Processing Record 39 of Set 11 | antalaha
# Processing Record 40 of Set 11 | mani
# Processing Record 41 of Set 11 | xiongshi
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 11 | mudon
# Processing Record 43 of Set 11 | abalak
# Processing Record 44 of Set 11 | olds
# Processing Record 45 of Set 11 | xunchang
# Processing Record 46 of Set 11 | kerur
# Processing Record 47 of Set 11 | samarai
# Processing Record 48 of Set 11 | itupiranga
# Processing Record 49 of Set 11 | charters towers
# Processing Record 50 of Set 11 | hobyo
# Processing Record 1 of Set 12 | qandala
# Processing Record 2 of Set 12 | wajima
# Processing Record 3 of Set 12 | mujiayingzi
# Processing Record 4 of Set 12 | baherden
# Processing Record 5 of Set 12 | japura
# Processing Record 6 of Set 12 | borovskoy
# Processing Record 7 of Set 12 | cajamarca
# Processing Record 8 of Set 12 | gazli
# Processing Record 9 of Set 12 | rawson
# Processing Record 10 of Set 12 | dali
# Processing Record 11 of Set 12 | hay river
# Processing Record 12 of Set 12 | bonavista
# Processing Record 13 of Set 12 | mount pleasant
# Processing Record 14 of Set 12 | pombas
# Processing Record 15 of Set 12 | sambava
# Processing Record 16 of Set 12 | yirol
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 12 | codrington
# Processing Record 18 of Set 12 | kalabo
# Processing Record 19 of Set 12 | korla
# Processing Record 20 of Set 12 | norden
# Processing Record 21 of Set 12 | milkovo
# Processing Record 22 of Set 12 | ventspils
# Processing Record 23 of Set 12 | vargem alta
# Processing Record 24 of Set 12 | bonanza
# Processing Record 25 of Set 12 | kudahuvadhoo
# Processing Record 26 of Set 12 | oranienburg
# Processing Record 27 of Set 12 | cagayan de tawi-tawi
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 12 | campeche
# Processing Record 29 of Set 12 | tall kayf
# Processing Record 30 of Set 12 | buraydah
# Processing Record 31 of Set 12 | mayo
# Processing Record 32 of Set 12 | qingyuan
# Processing Record 33 of Set 12 | lahat
# Processing Record 34 of Set 12 | meulaboh
# Processing Record 35 of Set 12 | yubari
# Processing Record 36 of Set 12 | santa lucia
# Processing Record 37 of Set 12 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 12 | smidovich
# Processing Record 39 of Set 12 | esmeraldas
# Processing Record 40 of Set 12 | tilichiki
# Processing Record 41 of Set 12 | shenjiamen
# Processing Record 42 of Set 12 | maceio
# Processing Record 43 of Set 12 | nemuro
# Processing Record 44 of Set 12 | khandbari
# Processing Record 45 of Set 12 | laem sing
# Processing Record 46 of Set 12 | krasnoarmeysk
# Processing Record 47 of Set 12 | grindavik
# Processing Record 48 of Set 12 | loukhi
# Processing Record 49 of Set 12 | samfya
# Processing Record 50 of Set 12 | petrove
# Processing Record 1 of Set 13 | marcona
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 13 | gladstone
# Processing Record 3 of Set 13 | luorong
# Processing Record 4 of Set 13 | ust-maya
# Processing Record 5 of Set 13 | panaba
# Processing Record 6 of Set 13 | galle
# Processing Record 7 of Set 13 | batagay
# Processing Record 8 of Set 13 | kalmunai
# Processing Record 9 of Set 13 | necochea
# Processing Record 10 of Set 13 | canico
# Processing Record 11 of Set 13 | vanimo
# Processing Record 12 of Set 13 | beisfjord
# Processing Record 13 of Set 13 | yarmouth
# Processing Record 14 of Set 13 | selenginsk
# Processing Record 15 of Set 13 | piet retief
# Processing Record 16 of Set 13 | sambalpur
# Processing Record 17 of Set 13 | beloha
# Processing Record 18 of Set 13 | annau
# Processing Record 19 of Set 13 | gemena
# Processing Record 20 of Set 13 | alugan
# Processing Record 21 of Set 13 | huadian
# Processing Record 22 of Set 13 | abeche
# Processing Record 23 of Set 13 | emerald
# Processing Record 24 of Set 13 | sedalia
# Processing Record 25 of Set 13 | kilindoni
# Processing Record 26 of Set 13 | cruz alta
# Processing Record 27 of Set 13 | ishigaki
# Processing Record 28 of Set 13 | qui nhon
# Processing Record 29 of Set 13 | shihezi
# Processing Record 30 of Set 13 | broken hill
# Processing Record 31 of Set 13 | bairiki
# Processing Record 32 of Set 13 | seoul
# Processing Record 33 of Set 13 | salalah
# Processing Record 34 of Set 13 | linhares
# Processing Record 35 of Set 13 | umm durman
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 13 | baker city
# Processing Record 37 of Set 13 | naze
# Processing Record 38 of Set 13 | prince rupert
# Processing Record 39 of Set 13 | port keats
# Processing Record 40 of Set 13 | nuuk
# Processing Record 41 of Set 13 | disna
# Processing Record 42 of Set 13 | la rochelle
# Processing Record 43 of Set 13 | worland
# Processing Record 44 of Set 13 | bubaque
# Processing Record 45 of Set 13 | nhulunbuy
# Processing Record 46 of Set 13 | ikole
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 13 | poltavka
# Processing Record 48 of Set 13 | kargasok
# Processing Record 49 of Set 13 | asau
# Processing Record 50 of Set 13 | itarema
# Processing Record 1 of Set 14 | aykhal
# Processing Record 2 of Set 14 | urengoy
# Processing Record 3 of Set 14 | kojori
# Processing Record 4 of Set 14 | mangrol
# Processing Record 5 of Set 14 | terenos
# Processing Record 6 of Set 14 | kearney
# Processing Record 7 of Set 14 | lisakovsk
# Processing Record 8 of Set 14 | berlevag
# Processing Record 9 of Set 14 | zhiryatino
# Processing Record 10 of Set 14 | suntar
# Processing Record 11 of Set 14 | soure
# Processing Record 12 of Set 14 | marjamaa
# Processing Record 13 of Set 14 | sioux lookout
# Processing Record 14 of Set 14 | havre-saint-pierre
# Processing Record 15 of Set 14 | urumqi
# Processing Record 16 of Set 14 | rancho palos verdes
# Processing Record 17 of Set 14 | tornio
# Processing Record 18 of Set 14 | balabac
# Processing Record 19 of Set 14 | road town
# Processing Record 20 of Set 14 | barahona
# Processing Record 21 of Set 14 | ciudad dario
# Processing Record 22 of Set 14 | honningsvag
# Processing Record 23 of Set 14 | stolin
# Processing Record 24 of Set 14 | port washington
# Processing Record 25 of Set 14 | avera
# Processing Record 26 of Set 14 | kroya
# Processing Record 27 of Set 14 | suao
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 14 | mon
# Processing Record 29 of Set 14 | pauini
# Processing Record 30 of Set 14 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 14 | duz
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 14 | cove
# Processing Record 33 of Set 14 | umarizal
# Processing Record 34 of Set 14 | lebedinyy
# Processing Record 35 of Set 14 | sao jose da coroa grande
# Processing Record 36 of Set 14 | poya
# Processing Record 37 of Set 14 | jinchengjiang
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 14 | houlton
# Processing Record 39 of Set 14 | morant bay
# Processing Record 40 of Set 14 | gizo
# Processing Record 41 of Set 14 | halalo
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 14 | sysert
# Processing Record 43 of Set 14 | mananjary
# Processing Record 44 of Set 14 | sakakah
# Processing Record 45 of Set 14 | porlamar
# Processing Record 46 of Set 14 | ola
# Processing Record 47 of Set 14 | madang
# Processing Record 48 of Set 14 | vallenar
# Processing Record 49 of Set 14 | ponta delgada
# Processing Record 50 of Set 14 | oksfjord
# Processing Record 1 of Set 15 | hebi
# Processing Record 2 of Set 15 | sungai padi
# Processing Record 3 of Set 15 | santa isabel do rio negro
# Processing Record 4 of Set 15 | djenne
# Processing Record 5 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 15 | khuzhir
# Processing Record 7 of Set 15 | namie
# Processing Record 8 of Set 15 | voyvozh
# Processing Record 9 of Set 15 | orlik
# Processing Record 10 of Set 15 | kuybyshevo
# Processing Record 11 of Set 15 | dalvik
# Processing Record 12 of Set 15 | ondjiva
# Processing Record 13 of Set 15 | ocampo
# Processing Record 14 of Set 15 | new amsterdam
# Processing Record 15 of Set 15 | ugoofaaru
# Processing Record 16 of Set 15 | vanderhoof
# Processing Record 17 of Set 15 | semme
# Processing Record 18 of Set 15 | nara
# Processing Record 19 of Set 15 | lufilufi
# Processing Record 20 of Set 15 | new castle
# Processing Record 21 of Set 15 | apaxco
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 15 | richards bay
# Processing Record 23 of Set 15 | kasongo
# Processing Record 24 of Set 15 | lensk
# Processing Record 25 of Set 15 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 15 | cockburn town
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mayumba  -3.4320   10.6554     78.35        86          60
# 1  Bambous Virieux -20.3428   57.7575     79.21        82          51
# 2      Komatipoort -25.4332   31.9548     72.05        88          58
# 3       Ridgecrest  35.6225 -117.6709     61.68        13           0
# 4            Bluff -46.6000  168.3333     38.80        81           2
# 5            Tiksi  71.6872  128.8694    -17.39        98         100
# 6          Rikitea -23.1203 -134.9692     79.02        71          66
# 7       Bredasdorp -34.5322   20.0403     66.27        55           6
# 8       Mto Wa Mbu  -3.3500   35.8500     71.01        80         100
# 9        Jamestown  42.0970  -79.2353     33.53        36           0
#
#    Wind Speed Country  Current Weather
# 0        5.37      GA    broken clouds
# 1       11.81      MU    broken clouds
# 2        8.28      ZA    broken clouds
# 3        4.00      US        clear sky
# 4        4.16      NZ        clear sky
# 5        2.89      RU  overcast clouds
# 6       16.06      PF    broken clouds
# 7        5.37      ZA        clear sky
# 8        5.75      TZ       light rain
# 9        5.01      US        clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
#export the City_Data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
